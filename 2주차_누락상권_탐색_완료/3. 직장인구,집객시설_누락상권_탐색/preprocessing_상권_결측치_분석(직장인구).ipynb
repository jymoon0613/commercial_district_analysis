# %% [markdown]
# ## 데이터 수집 및 전처리

# %% [markdown]
# ### 1. 통합 데이터파일 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("data_processed_final.csv")
data
# Out:
#        Unnamed: 0 상권_구분_코드_명    상권_코드          상권_코드_명  기준_년_코드  기준_분기_코드  \
# 0               0       전통시장  1001453            낙성대시장   2020.0       2.0
# 1               1       전통시장  1001454         봉천제일종합시장   2020.0       2.0
# 2               2       전통시장  1001474             도곡시장   2020.0       2.0
# 3               3       전통시장  1001475           강남개포시장   2020.0       2.0
# 4               4       전통시장  1001412           화곡본동시장   2020.0       2.0
# ...           ...        ...      ...              ...      ...       ...
# 32907       32907       발달상권  1001043     동작구 총신대입구역_2   2015.0       1.0
# 32908       32908       발달상권  1001044            양재역_3   2015.0       1.0
# 32909       32909       발달상권  1001030            양재역_2   2015.0       1.0
# 32910       32910       발달상권  1001031     서울 관악구 신림역_1   2015.0       1.0
# 32911       32911       발달상권  1001033  서울 서초구 남부터미널역_1   2015.0       1.0
#
#         총_유동인구_수  집객시설_수      당월_매출_금액  총_직장_인구_수  총 상주인구 수  아파트_단지_수  \
# ...

# %%
data=data.drop(['Unnamed: 0'],axis=1,inplace=False)
data
# Out:
#       상권_구분_코드_명    상권_코드          상권_코드_명  기준_년_코드  기준_분기_코드   총_유동인구_수  \
# 0           전통시장  1001453            낙성대시장   2020.0       2.0   189157.0
# 1           전통시장  1001454         봉천제일종합시장   2020.0       2.0    82738.0
# 2           전통시장  1001474             도곡시장   2020.0       2.0   284809.0
# 3           전통시장  1001475           강남개포시장   2020.0       2.0    45750.0
# 4           전통시장  1001412           화곡본동시장   2020.0       2.0   184732.0
# ...          ...      ...              ...      ...       ...        ...
# 32907       발달상권  1001043     동작구 총신대입구역_2   2015.0       1.0   773412.0
# 32908       발달상권  1001044            양재역_3   2015.0       1.0   856624.0
# 32909       발달상권  1001030            양재역_2   2015.0       1.0   838040.0
# 32910       발달상권  1001031     서울 관악구 신림역_1   2015.0       1.0  1199177.0
# 32911       발달상권  1001033  서울 서초구 남부터미널역_1   2015.0       1.0   345028.0
#
#        집객시설_수      당월_매출_금액  총_직장_인구_수  총 상주인구 수  아파트_단지_수  아파트_평균_면적  \
# ...

# %%
data.groupby(['기준_년_코드','기준_분기_코드']).size()
# Out:
# 기준_년_코드  기준_분기_코드
# 2015.0   1.0         1496
#          2.0         1496
#          3.0         1496
#          4.0         1496
# 2016.0   1.0         1496
#          2.0         1496
#          3.0         1496
#          4.0         1496
# 2017.0   1.0         1496
#          2.0         1496
#          3.0         1496
#          4.0         1496
# 2018.0   1.0         1496
#          2.0         1496
#          3.0         1496
#          4.0         1496
# 2019.0   1.0         1496
#          2.0         1496
#          3.0         1496
#          4.0         1496
# 2020.0   1.0         1496
#          2.0         1496
# dtype: int64

# %%
data.groupby(['기준_년_코드','기준_분기_코드','상권_구분_코드_명']).size()
# Out:
# 기준_년_코드  기준_분기_코드  상권_구분_코드_명
# 2015.0   1.0       골목상권          1010
#                    관광특구             6
#                    발달상권           253
#                    전통시장           227
#          2.0       골목상권          1010
#                                  ...
# 2020.0   1.0       전통시장           227
#          2.0       골목상권          1010
#                    관광특구             6
#                    발달상권           253
#                    전통시장           227
# Length: 88, dtype: int64

# %%
data.columns
# Out:
# Index(['상권_구분_코드_명', '상권_코드', '상권_코드_명', '기준_년_코드', '기준_분기_코드', '총_유동인구_수',
#        '집객시설_수', '당월_매출_금액', '총_직장_인구_수', '총 상주인구 수', '아파트_단지_수', '아파트_평균_면적',
#        '아파트_평균_시가'],
#       dtype='object')

# %% [markdown]
# ### 2. 전체 데이터 결측치 분석

# %%
data.isnull().any()
# Out:
# 상권_구분_코드_명    False
# 상권_코드         False
# 상권_코드_명       False
# 기준_년_코드       False
# 기준_분기_코드      False
# 총_유동인구_수       True
# 집객시설_수         True
# 당월_매출_금액       True
# 총_직장_인구_수      True
# 총 상주인구 수       True
# 아파트_단지_수       True
# 아파트_평균_면적      True
# 아파트_평균_시가      True
# dtype: bool

# %% [markdown]
# - 8개의 변수 모두 결측치 있음

# %%
data[['집객시설_수','총_직장_인구_수']].isnull().sum() #결측치 갯수
# Out:
# 집객시설_수       1436
# 총_직장_인구_수    2565
# dtype: int64

# %%
# %matplotlib inline
sns.heatmap(data.isnull(),cbar=True)
plt.rcParams['font.family'] = 'Malgun Gothic'
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# - 총 32912(1496개 상권x22개 분기)개의 전체 데이터에 대한 결측치의 분포 모습. 집객시설과 직장인구, 상주인구, 아파트 변수에서 공통적으로 결측치가 생기는 라인 관찰됨.

# %% [markdown]
# - 집객시설 수 : 2019년 1-4분기(2992부터 8976)+2017년 1-4분기(14961부터 20944)+2016년 1-4분기(20945부터 26928)+
#     2015년 1-4분기(26929부터 32912)에 결측치 존재

# %% [markdown]
# - 직장인구 수 : 2018년 1-4분기(8977부터 14960)+2017년 1-4분기(14961부터 20944)+2016년 1-4분기(20945부터 26928)+
#     2015년 1-4분기(26929부터 32912)에 결측치 존재

# %% [markdown]
# ### 3. 집객시설수, 직장인구수 변수 결측치 확인

# %%
data_std=pd.read_csv("data_상권/서울시 우리마을가게 상권분석서비스(상권영역).csv",encoding='cp949')
data_code=set(data_std['상권_코드'])
data_code
# Out:
# {1000001,
#  1000002,
#  1000003,
#  1000004,
#  1000005,
#  1000006,
#  1000007,
#  1000008,
#  1000009,
#  1000010,
#  1000011,
#  1000012,
#  1000013,
#  1000014,
#  1000015,
#  1000016,
#  1000017,
#  1000018,
#  1000019,
#  1000020,
#  1000021,
#  1000022,
#  1000023,
#  1000024,
#  1000025,
#  1000026,
#  1000027,
#  1000028,
#  1000029,
#  1000030,
#  1000031,
#  1000032,
#  1000033,
#  1000034,
#  1000035,
#  1000036,
#  1000037,
#  1000038,
#  1000039,
#  1000040,
#  1000041,
#  1000042,
#  1000043,
#  1000044,
#  1000045,
#  1000046,
#  1000047,
#  1000048,
#  1000049,
#  1000050,
#  1000051,
#  1000052,
#  1000053,
#  1000054,
#  1000055,
#  1000056,
#  1000057,
#  1000058,
#  1000059,
#  1000060,
#  1000061,
#  1000062,
#  1000063,
#  1000064,
#  1000065,
#  1000066,
#  1000067,
#  1000068,
#  1000069,
#  1000070,
#  1000071,
#  1000072,
#  1000073,
#  1000074,
#  1000075,
#  1000076,
#  1000077,
#  1000078,
#  1000079,
#  1000080,
#  1000081,
#  1000082,
#  1000083,
# ...

# %%
data_people=pd.read_csv("data_상권/서울시 우리마을가게 상권분석서비스(상권-직장인구)_new.csv",encoding='cp949')
data_people=data_people.drop(['Unnamed: 0','기준_분기_코드.1'],axis=1,inplace=False)
data_people=data_people.rename({'기준_년월_코드':'기준_년_코드'},axis='columns')
data_people
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0         2020         2       관광특구  1001496             강남 마이스 관광특구
# 1         2020         2       관광특구  1001495                 잠실 관광특구
# 2         2020         2       관광특구  1001494              종로?청계 관광특구
# 3         2020         2       관광특구  1001493            동대문패션타운 관광특구
# 4         2020         2       관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# ...        ...       ...        ...      ...                     ...
# 34377     2014         2       골목상권  1000006                  북촌로11길
# 34378     2014         2       골목상권  1000005                    백석동길
# 34379     2014         2       골목상권  1000004                     명륜길
# 34380     2014         2       골목상권  1000003                돈화문로11가길
# 34381     2014         2       골목상권  1000001                     계동길
#
#        총_직장_인구_수
# 0          15904
# 1          24375
# 2          32935
# 3           6054
# 4         104830
# ...          ...
# ...

# %%
data_2015_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2015,1))
data_2015_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2015,2))
data_2015_3=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2015,3))
data_2015_4=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2015,4))
data_2016_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2016,1))
data_2016_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2016,2))
data_2016_3=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2016,3))
data_2016_4=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2016,4))
data_2017_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2017,1))
data_2017_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2017,2))
data_2017_3=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2017,3))
data_2017_4=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2017,4))
data_2018_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2018,1))
data_2018_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2018,2))
data_2018_3=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2018,3))
data_2018_4=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2018,4))
data_2019_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2019,1))
data_2019_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2019,2))
data_2019_3=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2019,3))
data_2019_4=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2019,4))
data_2020_1=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2020,1))
data_2020_2=data_people.groupby(['기준_년_코드','기준_분기_코드']).get_group((2020,2))

# %%
print(len(data_2015_1))
print(len(data_2015_2))
print(len(data_2015_3))
print(len(data_2015_4))
print(len(data_2016_1))
print(len(data_2016_2))
print(len(data_2016_3))
print(len(data_2016_4))
print(len(data_2017_1))
print(len(data_2017_2))
print(len(data_2017_3))
print(len(data_2017_4))
print(len(data_2018_1))
print(len(data_2018_2))
print(len(data_2018_3))
print(len(data_2018_4))
print(len(data_2019_1))
print(len(data_2019_2))
print(len(data_2019_3))
print(len(data_2019_4))
print(len(data_2020_1))
print(len(data_2020_2))
# Out:
# 1337
# 1339
# 1339
# 1341
# 1341
# 1343
# 1343
# 1343
# 1343
# 1343
# 1343
# 1341
# 1341
# 1343
# 1343
# 1343
# 1492
# 1493
# 1493
# 1475
# 1475
# 1475

# %%
code_2015_1 = set(data_2015_1['상권_코드'])
code_2015_2 = set(data_2015_2['상권_코드'])
code_2015_3 = set(data_2015_3['상권_코드'])
code_2015_4 = set(data_2015_4['상권_코드'])
code_2016_1 = set(data_2016_1['상권_코드'])
code_2016_2 = set(data_2016_2['상권_코드'])
code_2016_3 = set(data_2016_3['상권_코드'])
code_2016_4 = set(data_2016_4['상권_코드'])
code_2017_1 = set(data_2017_1['상권_코드'])
code_2017_2 = set(data_2017_2['상권_코드'])
code_2017_3 = set(data_2017_3['상권_코드'])
code_2017_4 = set(data_2017_4['상권_코드'])
code_2018_1 = set(data_2018_1['상권_코드'])
code_2018_2 = set(data_2018_2['상권_코드'])
code_2018_3 = set(data_2018_3['상권_코드'])
code_2018_4 = set(data_2018_4['상권_코드'])
code_2019_1 = set(data_2019_1['상권_코드'])
code_2019_2 = set(data_2019_2['상권_코드'])
code_2019_3 = set(data_2019_3['상권_코드'])
code_2019_4 = set(data_2019_4['상권_코드'])
code_2020_1 = set(data_2020_1['상권_코드'])
code_2020_2 = set(data_2020_2['상권_코드'])

# %%
code_miss_2015_1=data_code - code_2015_1
code_miss_2015_2=data_code - code_2015_2
code_miss_2015_3=data_code - code_2015_3
code_miss_2015_4=data_code - code_2015_4
code_miss_2016_1=data_code - code_2016_1
code_miss_2016_2=data_code - code_2016_2
code_miss_2016_3=data_code - code_2016_3
code_miss_2016_4=data_code - code_2016_4
code_miss_2017_1=data_code - code_2017_1
code_miss_2017_2=data_code - code_2017_2
code_miss_2017_3=data_code - code_2017_3
code_miss_2017_4=data_code - code_2017_4
code_miss_2018_1=data_code - code_2018_1
code_miss_2018_2=data_code - code_2018_2
code_miss_2018_3=data_code - code_2018_3
code_miss_2018_4=data_code - code_2018_4
code_miss_2019_1=data_code - code_2019_1
code_miss_2019_2=data_code - code_2019_2
code_miss_2019_3=data_code - code_2019_3
code_miss_2019_4=data_code - code_2019_4
code_miss_2020_1=data_code - code_2020_1
code_miss_2020_2=data_code - code_2020_2

# %%
code_miss_list = [code_miss_2015_1,code_miss_2015_2,code_miss_2015_3,code_miss_2015_4,
           code_miss_2016_1,code_miss_2016_2,code_miss_2016_3,code_miss_2016_4,
           code_miss_2017_1,code_miss_2017_2,code_miss_2017_3,code_miss_2017_4,
           code_miss_2018_1,code_miss_2018_2,code_miss_2018_3,code_miss_2018_4,
           code_miss_2019_1,code_miss_2019_2,code_miss_2019_3,code_miss_2019_4,code_miss_2020_1,code_miss_2020_2]

# %%
print("{}_{} : {}".format(2015,1,code_miss_2015_1))
print("{}_{} : {}".format(2015,2,code_miss_2015_2))
print("{}_{} : {}".format(2015,3,code_miss_2015_3))
print("{}_{} : {}".format(2015,4,code_miss_2015_4))
print("{}_{} : {}".format(2015,1,code_miss_2016_1))
print("{}_{} : {}".format(2016,2,code_miss_2016_2))
print("{}_{} : {}".format(2016,3,code_miss_2016_3))
print("{}_{} : {}".format(2016,4,code_miss_2016_4))
print("{}_{} : {}".format(2017,1,code_miss_2017_1))
print("{}_{} : {}".format(2017,2,code_miss_2017_2))
print("{}_{} : {}".format(2017,3,code_miss_2017_3))
print("{}_{} : {}".format(2017,4,code_miss_2017_4))
print("{}_{} : {}".format(2018,1,code_miss_2018_1))
print("{}_{} : {}".format(2018,2,code_miss_2018_2))
print("{}_{} : {}".format(2018,3,code_miss_2018_3))
print("{}_{} : {}".format(2018,4,code_miss_2018_4))
print("{}_{} : {}".format(2019,1,code_miss_2019_1))
print("{}_{} : {}".format(2019,2,code_miss_2019_2))
print("{}_{} : {}".format(2019,3,code_miss_2019_3))
print("{}_{} : {}".format(2019,4,code_miss_2019_4))
print("{}_{} : {}".format(2020,1,code_miss_2020_1))
print("{}_{} : {}".format(2020,2,code_miss_2020_2))
# Out:
# 2015_1 : {1001472, 1001473, 1000970, 1001484, 1001485, 1001486, 1001465, 1000996, 1000997, 1001014, 1001017, 1000002, 1000520, 1001036, 1001040, 1000017, 1000018, 1000027, 1000540, 1001053, 1000038, 1001064, 1001065, 1001068, 1001069, 1001079, 1001083, 1000083, 1000092, 1001116, 1001126, 1001128, 1001148, 1000125, 1001154, 1001157, 1001174, 1001176, 1001177, 1000163, 1001191, 1000169, 1001219, 1000725, 1000726, 1001237, 1001258, 1001262, 1001264, 1001269, 1001272, 1000764, 1001276, 1000767, 1001279, 1000262, 1000775, 1001287, 1001288, 1001290, 1001291, 1001292, 1001293, 1000271, 1000272, 1000275, 1001300, 1001302, 1001303, 1001305, 1001306, 1001311, 1001312, 1000801, 1001314, 1001315, 1001318, 1001320, 1000297, 1000809, 1001322, 1001324, 1001325, 1001327, 1001328, 1001331, 1000821, 1001337, 1000316, 1001341, 1001342, 1001344, 1001345, 1001346, 1001348, 1001350, 1000841, 1000330, 1001358, 1001360, 1001362, 1000340, 1001365, 1001366, 1001368, 1001369, 1001370, 1001371, 1001372, 1001373
# ...

# %%
code_list = list(data_std['상권_코드'])
name_list = list(data_std['상권_코드_명'])

# %%
total_name_list = []
for code in code_miss_list:
    code_name_list = []
    for c in code:
        ind = code_list.index(c)
        name = name_list[ind]
        code_name_list.append(name)
    total_name_list.append(code_name_list)

# %%
len(total_name_list) #22개 분기
# Out:
# 22

# %%
print("{}_{} : {}".format(2015,1,total_name_list[0]))
print("{}_{} : {}".format(2015,2,total_name_list[1]))
print("{}_{} : {}".format(2015,3,total_name_list[2]))
print("{}_{} : {}".format(2015,4,total_name_list[3]))
print("{}_{} : {}".format(2016,1,total_name_list[4]))
print("{}_{} : {}".format(2016,2,total_name_list[5]))
print("{}_{} : {}".format(2016,3,total_name_list[6]))
print("{}_{} : {}".format(2016,4,total_name_list[7]))
print("{}_{} : {}".format(2017,1,total_name_list[8]))
print("{}_{} : {}".format(2017,2,total_name_list[9]))
print("{}_{} : {}".format(2017,3,total_name_list[10]))
print("{}_{} : {}".format(2017,4,total_name_list[11]))
print("{}_{} : {}".format(2018,1,total_name_list[12]))
print("{}_{} : {}".format(2018,2,total_name_list[13]))
print("{}_{} : {}".format(2018,3,total_name_list[14]))
print("{}_{} : {}".format(2018,4,total_name_list[15]))
print("{}_{} : {}".format(2019,1,total_name_list[16]))
print("{}_{} : {}".format(2019,2,total_name_list[17]))
print("{}_{} : {}".format(2019,3,total_name_list[18]))
print("{}_{} : {}".format(2019,4,total_name_list[19]))
print("{}_{} : {}".format(2020,1,total_name_list[20]))
print("{}_{} : {}".format(2020,2,total_name_list[21]))
# Out:
# 2015_1 : ['논현종합시장', '청담삼익시장', '고덕로61길', '양지골목시장', '고분다리골목시장', '동서울시장', '신신림시장', '올림픽로78길', '올림픽로80길', '양재동 꽃시장', '관악구 사당역_3', '난계로27길', '목동동로8길', '문정역', '서울 관악구 신림역_3', '종로24길', '종로58가길', '필운대로1길', '은행정로5길', '서울 강남구 대치역_1', '동호로8길', '대림역_1', '은마아파트입구사거리_1', '은마아파트입구사거리_2', '은마아파트입구사거리_3', '석촌역', '서울 송파구 석촌역_2', '한강대로88길', '뚝섬로5길', '영등포역_1', '서울 양천구 신정네거리역_2', '청담사거리_1', '목동사거리', '한림말3길', '용산 전자상가_4', '서울 강동구 천호역_1', '등촌역', '서울 중구 약수역_1', '서울 중구 약수역_2', '자양로53길', '왕십리역_1', '경희대로4길', '서울 종로구 동대문역_1', '여의대방로61길', '영등포로25길', '서울 종로구 경복궁역_2', '등나무근린공원 주변', '서울 노원구 노원역_2', '통인시장', '동문시장', '신설종합시장', '서달로15길', '평화시장', '성대로29길', '동평화시장', '돌곶이로14길', '장승배기로10길', '신흥시장', '만리시장', '이촌종합시장', '이태원시장', '이태원제일시장', '보광시장', '동소문로2길', '동소문로6길', '보문로26길', '화양제일골목시장', '면곡골목시장', '신성골목시장', '자양종합시장', '노룬산골목시장', '동부청과시장', '용두시장', '남현2길', '경동시장', '동서시장', '청량리전통시장', '전농로터리시장', '정릉로26길', '법원단지길', '동부시장', '전곡시장', '청량리청과물시장', '이경시장', '이문제일시장', '면목골목시장', '신림로65길', '유영시장', '노해로23길', '길음시장', '밤나무골시장', '번동시장', '새석관시장',
# ...

# %%
for i in range (0,len(total_name_list)):
    print(len(total_name_list[i]))
# Out:
# 159
# 157
# 157
# 155
# 155
# 153
# 153
# 153
# 153
# 153
# 153
# 155
# 155
# 153
# 153
# 153
# 4
# 3
# 3
# 21
# 21
# 21
